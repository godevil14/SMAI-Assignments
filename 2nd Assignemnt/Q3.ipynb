# %% [markdown]
# # SMAI Assignment - 2
#
# ## Question 3: Face Recognition using Principal Component Analysis
#
# This question requires you to create a basic facial recognition system using a technique called principal component analysis (PCA)
# by projecting the face images on the feature space (face space) which best
# represents the variations among distinct faces. The face space is defined as the
# “Eigenfaces", which are the eigenvectors of the set of faces.
#
# The goal of implementing this system is to recognize a person's face by comparing it to a pre-existing database of faces, and identifying the closest match.
#
# Link to paper on Eigenfaces: [https://sites.cs.ucsb.edu/~mturk/Papers/mturk-CVPR91.pdf](https://sites.cs.ucsb.edu/~mturk/Papers/mturk-CVPR91.pdf)
#
# The AT&T face dataset contains a set of grayscale face images with dimensions 92x112. The images are organised in 40 directories (one for each subject), which have names of the form sX, where X indicates the subject number (between 1 and 40). In each of these directories, there are ten different images of that subject, which have names of the form Y.pgm, where Y is the image number for that subject (between 1 and 10). These 10 images per person are taken at different times, varying the lighting, facial expressions (open / closed eyes, smiling / not smiling) and facial details (glasses / no glasses). All the images were taken against a dark homogeneous background with the subjects in an upright, frontal position (with tolerance for some side movement). <b>Link:</b> [https://git-disl.github.io/GTDLBench/datasets/att_face_dataset/](https://git-disl.github.io/GTDLBench/datasets/att_face_dataset/)

# %% [markdown]
# #### Tasks
# 1. Load dataset and divide the date into training and test sets.
# 2. Implement the PCA algorithm from scratch.
# 3. Implement image reconstruction using the eigen projections and visualise differences for different number of components.
# 4. Visualise the mean(Eigen face) generated.
# 5. Given training set, obtain accuracy by attempting a face regonition module and obtaining the accuracy for different number of principal components.

# %% [markdown]
# #### Import Libraries

# %%
# !unzip ATnT.zip
# Out:
# Archive:  ATnT.zip
#   inflating: ATnT/README
#    creating: ATnT/s1/
#   inflating: ATnT/s1/1.pgm
#   inflating: ATnT/s1/10.pgm
#   inflating: ATnT/s1/2.pgm
#   inflating: ATnT/s1/3.pgm
#   inflating: ATnT/s1/4.pgm
#   inflating: ATnT/s1/5.pgm
#   inflating: ATnT/s1/6.pgm
#   inflating: ATnT/s1/7.pgm
#   inflating: ATnT/s1/8.pgm
#   inflating: ATnT/s1/9.pgm
#    creating: ATnT/s10/
#   inflating: ATnT/s10/1.pgm
#   inflating: ATnT/s10/10.pgm
#   inflating: ATnT/s10/2.pgm
#   inflating: ATnT/s10/3.pgm
#   inflating: ATnT/s10/4.pgm
#   inflating: ATnT/s10/5.pgm
#   inflating: ATnT/s10/6.pgm
#   inflating: ATnT/s10/7.pgm
#   inflating: ATnT/s10/8.pgm
#   inflating: ATnT/s10/9.pgm
#    creating: ATnT/s11/
#   inflating: ATnT/s11/1.pgm
#   inflating: ATnT/s11/10.pgm
#   inflating: ATnT/s11/2.pgm
#   inflating: ATnT/s11/3.pgm
#   inflating: ATnT/s11/4.pgm
#   inflating: ATnT/s11/5.pgm
#   inflating: ATnT/s11/6.pgm
#   inflating: ATnT/s11/7.pgm
#   inflating: ATnT/s11/8.pgm
#   inflating: ATnT/s11/9.pgm
#    creating: ATnT/s12/
#   inflating: ATnT/s12/1.pgm
#   inflating: ATnT/s12/10.pgm
#   inflating: ATnT/s12/2.pgm
#   inflating: ATnT/s12/3.pgm
#   inflating: ATnT/s12/4.pgm
#   inflating: ATnT/s12/5.pgm
#   inflating: ATnT/s12/6.pgm
#   inflating: ATnT/s12/7.pgm
#   inflating: ATnT/s12/8.pgm
#   inflating: ATnT/s12/9.pgm
#    creating: ATnT/s13/
#   inflating: ATnT/s13/1.pgm
#   inflating: ATnT/s13/10.pgm
#   inflating: ATnT/s13/2.pgm
#   inflating: ATnT/s13/3.pgm
#   inflating: ATnT/s13/4.pgm
#   inflating: ATnT/s13/5.pgm
#   inflating: ATnT/s13/6.pgm
#   inflating: ATnT/s13/7.pgm
#   inflating: ATnT/s13/8.pgm
#   inflating: ATnT/s13/9.pgm
#    creating: ATnT/s14/
#   inflating: ATnT/s14/1.pgm
#   inflating: ATnT/s14/10.pgm
#   inflating: ATnT/s14/2.pgm
#   inflating: ATnT/s14/3.pgm
#   inflating: ATnT/s14/4.pgm
#   inflating: ATnT/s14/5.pgm
#   inflating: ATnT/s14/6.pgm
#   inflating: ATnT/s14/7.pgm
#   inflating: ATnT/s14/8.pgm
#   inflating: ATnT/s14/9.pgm
#    creating: ATnT/s15/
#   inflating: ATnT/s15/1.pgm
#   inflating: ATnT/s15/10.pgm
#   inflating: ATnT/s15/2.pgm
#   inflating: ATnT/s15/3.pgm
#   inflating: ATnT/s15/4.pgm
#   inflating: ATnT/s15/5.pgm
#   inflating: ATnT/s15/6.pgm
#   inflating: ATnT/s15/7.pgm
#   inflating: ATnT/s15/8.pgm
#   inflating: ATnT/s15/9.pgm
#    creating: ATnT/s16/
#   inflating: ATnT/s16/1.pgm
#   inflating: ATnT/s16/10.pgm
#   inflating: ATnT/s16/2.pgm
#   inflating: ATnT/s16/3.pgm
#   inflating: ATnT/s16/4.pgm
#   inflating: ATnT/s16/5.pgm
#   inflating: ATnT/s16/6.pgm
#   inflating: ATnT/s16/7.pgm
#   inflating: ATnT/s16/8.pgm
#   inflating: ATnT/s16/9.pgm
#    creating: ATnT/s17/
#   inflating: ATnT/s17/1.pgm
#   inflating: ATnT/s17/10.pgm
#   inflating: ATnT/s17/2.pgm
#   inflating: ATnT/s17/3.pgm
#   inflating: ATnT/s17/4.pgm
#   inflating: ATnT/s17/5.pgm
#   inflating: ATnT/s17/6.pgm
#   inflating: ATnT/s17/7.pgm
#   inflating: ATnT/s17/8.pgm
#   inflating: ATnT/s17/9.pgm
#    creating: ATnT/s18/
#   inflating: ATnT/s18/1.pgm
#   inflating: ATnT/s18/10.pgm
#   inflating: ATnT/s18/2.pgm
#   inflating: ATnT/s18/3.pgm
#   inflating: ATnT/s18/4.pgm
#   inflating: ATnT/s18/5.pgm
#   inflating: ATnT/s18/6.pgm
#   inflating: ATnT/s18/7.pgm
#   inflating: ATnT/s18/8.pgm
#   inflating: ATnT/s18/9.pgm
#    creating: ATnT/s19/
#   inflating: ATnT/s19/1.pgm
#   inflating: ATnT/s19/10.pgm
#   inflating: ATnT/s19/2.pgm
#   inflating: ATnT/s19/3.pgm
#   inflating: ATnT/s19/4.pgm
#   inflating: ATnT/s19/5.pgm
#   inflating: ATnT/s19/6.pgm
#   inflating: ATnT/s19/7.pgm
#   inflating: ATnT/s19/8.pgm
#   inflating: ATnT/s19/9.pgm
#    creating: ATnT/s2/
#   inflating: ATnT/s2/1.pgm
#   inflating: ATnT/s2/10.pgm
#   inflating: ATnT/s2/2.pgm
#   inflating: ATnT/s2/3.pgm
#   inflating: ATnT/s2/4.pgm
#   inflating: ATnT/s2/5.pgm
#   inflating: ATnT/s2/6.pgm
#   inflating: ATnT/s2/7.pgm
#   inflating: ATnT/s2/8.pgm
#   inflating: ATnT/s2/9.pgm
#    creating: ATnT/s20/
#   inflating: ATnT/s20/1.pgm
#   inflating: ATnT/s20/10.pgm
#   inflating: ATnT/s20/2.pgm
#   inflating: ATnT/s20/3.pgm
#   inflating: ATnT/s20/4.pgm
#   inflating: ATnT/s20/5.pgm
#   inflating: ATnT/s20/6.pgm
#   inflating: ATnT/s20/7.pgm
#   inflating: ATnT/s20/8.pgm
#   inflating: ATnT/s20/9.pgm
#    creating: ATnT/s21/
#   inflating: ATnT/s21/1.pgm
#   inflating: ATnT/s21/10.pgm
#   inflating: ATnT/s21/2.pgm
#   inflating: ATnT/s21/3.pgm
#   inflating: ATnT/s21/4.pgm
#   inflating: ATnT/s21/5.pgm
#   inflating: ATnT/s21/6.pgm
#   inflating: ATnT/s21/7.pgm
#   inflating: ATnT/s21/8.pgm
#   inflating: ATnT/s21/9.pgm
#    creating: ATnT/s22/
#   inflating: ATnT/s22/1.pgm
#   inflating: ATnT/s22/10.pgm
#   inflating: ATnT/s22/2.pgm
#   inflating: ATnT/s22/3.pgm
#   inflating: ATnT/s22/4.pgm
#   inflating: ATnT/s22/5.pgm
#   inflating: ATnT/s22/6.pgm
#   inflating: ATnT/s22/7.pgm
#   inflating: ATnT/s22/8.pgm
#   inflating: ATnT/s22/9.pgm
#    creating: ATnT/s23/
#   inflating: ATnT/s23/1.pgm
#   inflating: ATnT/s23/10.pgm
#   inflating: ATnT/s23/2.pgm
#   inflating: ATnT/s23/3.pgm
#   inflating: ATnT/s23/4.pgm
#   inflating: ATnT/s23/5.pgm
#   inflating: ATnT/s23/6.pgm
#   inflating: ATnT/s23/7.pgm
#   inflating: ATnT/s23/8.pgm
#   inflating: ATnT/s23/9.pgm
#    creating: ATnT/s24/
#   inflating: ATnT/s24/1.pgm
#   inflating: ATnT/s24/10.pgm
#   inflating: ATnT/s24/2.pgm
#   inflating: ATnT/s24/3.pgm
#   inflating: ATnT/s24/4.pgm
#   inflating: ATnT/s24/5.pgm
#   inflating: ATnT/s24/6.pgm
#   inflating: ATnT/s24/7.pgm
#   inflating: ATnT/s24/8.pgm
#   inflating: ATnT/s24/9.pgm
#    creating: ATnT/s25/
#   inflating: ATnT/s25/1.pgm
#   inflating: ATnT/s25/10.pgm
#   inflating: ATnT/s25/2.pgm
#   inflating: ATnT/s25/3.pgm
#   inflating: ATnT/s25/4.pgm
#   inflating: ATnT/s25/5.pgm
#   inflating: ATnT/s25/6.pgm
#   inflating: ATnT/s25/7.pgm
#   inflating: ATnT/s25/8.pgm
#   inflating: ATnT/s25/9.pgm
#    creating: ATnT/s26/
#   inflating: ATnT/s26/1.pgm
#   inflating: ATnT/s26/10.pgm
#   inflating: ATnT/s26/2.pgm
#   inflating: ATnT/s26/3.pgm
#   inflating: ATnT/s26/4.pgm
#   inflating: ATnT/s26/5.pgm
#   inflating: ATnT/s26/6.pgm
#   inflating: ATnT/s26/7.pgm
#   inflating: ATnT/s26/8.pgm
#   inflating: ATnT/s26/9.pgm
#    creating: ATnT/s27/
#   inflating: ATnT/s27/1.pgm
#   inflating: ATnT/s27/10.pgm
#   inflating: ATnT/s27/2.pgm
#   inflating: ATnT/s27/3.pgm
#   inflating: ATnT/s27/4.pgm
#   inflating: ATnT/s27/5.pgm
#   inflating: ATnT/s27/6.pgm
#   inflating: ATnT/s27/7.pgm
#   inflating: ATnT/s27/8.pgm
#   inflating: ATnT/s27/9.pgm
#    creating: ATnT/s28/
#   inflating: ATnT/s28/1.pgm
#   inflating: ATnT/s28/10.pgm
#   inflating: ATnT/s28/2.pgm
#   inflating: ATnT/s28/3.pgm
#   inflating: ATnT/s28/4.pgm
#   inflating: ATnT/s28/5.pgm
#   inflating: ATnT/s28/6.pgm
#   inflating: ATnT/s28/7.pgm
#   inflating: ATnT/s28/8.pgm
#   inflating: ATnT/s28/9.pgm
#    creating: ATnT/s29/
#   inflating: ATnT/s29/1.pgm
#   inflating: ATnT/s29/10.pgm
#   inflating: ATnT/s29/2.pgm
#   inflating: ATnT/s29/3.pgm
#   inflating: ATnT/s29/4.pgm
#   inflating: ATnT/s29/5.pgm
#   inflating: ATnT/s29/6.pgm
#   inflating: ATnT/s29/7.pgm
#   inflating: ATnT/s29/8.pgm
#   inflating: ATnT/s29/9.pgm
#    creating: ATnT/s3/
#   inflating: ATnT/s3/1.pgm
#   inflating: ATnT/s3/10.pgm
#   inflating: ATnT/s3/2.pgm
#   inflating: ATnT/s3/3.pgm
#   inflating: ATnT/s3/4.pgm
#   inflating: ATnT/s3/5.pgm
#   inflating: ATnT/s3/6.pgm
#   inflating: ATnT/s3/7.pgm
#   inflating: ATnT/s3/8.pgm
#   inflating: ATnT/s3/9.pgm
#    creating: ATnT/s30/
#   inflating: ATnT/s30/1.pgm
#   inflating: ATnT/s30/10.pgm
#   inflating: ATnT/s30/2.pgm
#   inflating: ATnT/s30/3.pgm
#   inflating: ATnT/s30/4.pgm
#   inflating: ATnT/s30/5.pgm
#   inflating: ATnT/s30/6.pgm
#   inflating: ATnT/s30/7.pgm
#   inflating: ATnT/s30/8.pgm
#   inflating: ATnT/s30/9.pgm
#    creating: ATnT/s31/
#   inflating: ATnT/s31/1.pgm
#   inflating: ATnT/s31/10.pgm
#   inflating: ATnT/s31/2.pgm
#   inflating: ATnT/s31/3.pgm
#   inflating: ATnT/s31/4.pgm
#   inflating: ATnT/s31/5.pgm
#   inflating: ATnT/s31/6.pgm
#   inflating: ATnT/s31/7.pgm
#   inflating: ATnT/s31/8.pgm
#   inflating: ATnT/s31/9.pgm
#    creating: ATnT/s32/
#   inflating: ATnT/s32/1.pgm
#   inflating: ATnT/s32/10.pgm
#   inflating: ATnT/s32/2.pgm
#   inflating: ATnT/s32/3.pgm
#   inflating: ATnT/s32/4.pgm
#   inflating: ATnT/s32/5.pgm
#   inflating: ATnT/s32/6.pgm
#   inflating: ATnT/s32/7.pgm
#   inflating: ATnT/s32/8.pgm
#   inflating: ATnT/s32/9.pgm
#    creating: ATnT/s33/
#   inflating: ATnT/s33/1.pgm
#   inflating: ATnT/s33/10.pgm
#   inflating: ATnT/s33/2.pgm
#   inflating: ATnT/s33/3.pgm
#   inflating: ATnT/s33/4.pgm
#   inflating: ATnT/s33/5.pgm
#   inflating: ATnT/s33/6.pgm
#   inflating: ATnT/s33/7.pgm
#   inflating: ATnT/s33/8.pgm
#   inflating: ATnT/s33/9.pgm
#    creating: ATnT/s34/
#   inflating: ATnT/s34/1.pgm
#   inflating: ATnT/s34/10.pgm
#   inflating: ATnT/s34/2.pgm
#   inflating: ATnT/s34/3.pgm
#   inflating: ATnT/s34/4.pgm
#   inflating: ATnT/s34/5.pgm
#   inflating: ATnT/s34/6.pgm
#   inflating: ATnT/s34/7.pgm
#   inflating: ATnT/s34/8.pgm
#   inflating: ATnT/s34/9.pgm
#    creating: ATnT/s35/
#   inflating: ATnT/s35/1.pgm
#   inflating: ATnT/s35/10.pgm
#   inflating: ATnT/s35/2.pgm
#   inflating: ATnT/s35/3.pgm
#   inflating: ATnT/s35/4.pgm
#   inflating: ATnT/s35/5.pgm
#   inflating: ATnT/s35/6.pgm
#   inflating: ATnT/s35/7.pgm
#   inflating: ATnT/s35/8.pgm
#   inflating: ATnT/s35/9.pgm
#    creating: ATnT/s36/
#   inflating: ATnT/s36/1.pgm
#   inflating: ATnT/s36/10.pgm
#   inflating: ATnT/s36/2.pgm
#   inflating: ATnT/s36/3.pgm
#   inflating: ATnT/s36/4.pgm
#   inflating: ATnT/s36/5.pgm
#   inflating: ATnT/s36/6.pgm
#   inflating: ATnT/s36/7.pgm
#   inflating: ATnT/s36/8.pgm
#   inflating: ATnT/s36/9.pgm
#    creating: ATnT/s37/
#   inflating: ATnT/s37/1.pgm
#   inflating: ATnT/s37/10.pgm
#   inflating: ATnT/s37/2.pgm
#   inflating: ATnT/s37/3.pgm
#   inflating: ATnT/s37/4.pgm
#   inflating: ATnT/s37/5.pgm
#   inflating: ATnT/s37/6.pgm
#   inflating: ATnT/s37/7.pgm
#   inflating: ATnT/s37/8.pgm
#   inflating: ATnT/s37/9.pgm
#    creating: ATnT/s38/
#   inflating: ATnT/s38/1.pgm
#   inflating: ATnT/s38/10.pgm
#   inflating: ATnT/s38/2.pgm
#   inflating: ATnT/s38/3.pgm
#   inflating: ATnT/s38/4.pgm
#   inflating: ATnT/s38/5.pgm
#   inflating: ATnT/s38/6.pgm
#   inflating: ATnT/s38/7.pgm
#   inflating: ATnT/s38/8.pgm
#   inflating: ATnT/s38/9.pgm
#    creating: ATnT/s39/
#   inflating: ATnT/s39/1.pgm
#   inflating: ATnT/s39/10.pgm
#   inflating: ATnT/s39/2.pgm
#   inflating: ATnT/s39/3.pgm
#   inflating: ATnT/s39/4.pgm
#   inflating: ATnT/s39/5.pgm
#   inflating: ATnT/s39/6.pgm
#   inflating: ATnT/s39/7.pgm
#   inflating: ATnT/s39/8.pgm
#   inflating: ATnT/s39/9.pgm
#    creating: ATnT/s4/
#   inflating: ATnT/s4/1.pgm
#   inflating: ATnT/s4/10.pgm
#   inflating: ATnT/s4/2.pgm
#   inflating: ATnT/s4/3.pgm
#   inflating: ATnT/s4/4.pgm
#   inflating: ATnT/s4/5.pgm
#   inflating: ATnT/s4/6.pgm
#   inflating: ATnT/s4/7.pgm
#   inflating: ATnT/s4/8.pgm
#   inflating: ATnT/s4/9.pgm
#    creating: ATnT/s40/
#   inflating: ATnT/s40/1.pgm
#   inflating: ATnT/s40/10.pgm
#   inflating: ATnT/s40/2.pgm
#   inflating: ATnT/s40/3.pgm
#   inflating: ATnT/s40/4.pgm
#   inflating: ATnT/s40/5.pgm
#   inflating: ATnT/s40/6.pgm
#   inflating: ATnT/s40/7.pgm
#   inflating: ATnT/s40/8.pgm
#   inflating: ATnT/s40/9.pgm
#    creating: ATnT/s5/
#   inflating: ATnT/s5/1.pgm
#   inflating: ATnT/s5/10.pgm
#   inflating: ATnT/s5/2.pgm
#   inflating: ATnT/s5/3.pgm
#   inflating: ATnT/s5/4.pgm
#   inflating: ATnT/s5/5.pgm
#   inflating: ATnT/s5/6.pgm
#   inflating: ATnT/s5/7.pgm
#   inflating: ATnT/s5/8.pgm
#   inflating: ATnT/s5/9.pgm
#    creating: ATnT/s6/
#   inflating: ATnT/s6/1.pgm
#   inflating: ATnT/s6/10.pgm
#   inflating: ATnT/s6/2.pgm
#   inflating: ATnT/s6/3.pgm
#   inflating: ATnT/s6/4.pgm
#   inflating: ATnT/s6/5.pgm
#   inflating: ATnT/s6/6.pgm
#   inflating: ATnT/s6/7.pgm
#   inflating: ATnT/s6/8.pgm
#   inflating: ATnT/s6/9.pgm
#    creating: ATnT/s7/
#   inflating: ATnT/s7/1.pgm
#   inflating: ATnT/s7/10.pgm
#   inflating: ATnT/s7/2.pgm
#   inflating: ATnT/s7/3.pgm
#   inflating: ATnT/s7/4.pgm
#   inflating: ATnT/s7/5.pgm
#   inflating: ATnT/s7/6.pgm
#   inflating: ATnT/s7/7.pgm
#   inflating: ATnT/s7/8.pgm
#   inflating: ATnT/s7/9.pgm
#    creating: ATnT/s8/
#   inflating: ATnT/s8/1.pgm
#   inflating: ATnT/s8/10.pgm
#   inflating: ATnT/s8/2.pgm
#   inflating: ATnT/s8/3.pgm
#   inflating: ATnT/s8/4.pgm
#   inflating: ATnT/s8/5.pgm
#   inflating: ATnT/s8/6.pgm
#   inflating: ATnT/s8/7.pgm
#   inflating: ATnT/s8/8.pgm
#   inflating: ATnT/s8/9.pgm
#    creating: ATnT/s9/
#   inflating: ATnT/s9/1.pgm
#   inflating: ATnT/s9/10.pgm
#   inflating: ATnT/s9/2.pgm
#   inflating: ATnT/s9/3.pgm
#   inflating: ATnT/s9/4.pgm
#   inflating: ATnT/s9/5.pgm
#   inflating: ATnT/s9/6.pgm
#   inflating: ATnT/s9/7.pgm
#   inflating: ATnT/s9/8.pgm
#   inflating: ATnT/s9/9.pgm

# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import cv2
from copy import copy
from tqdm import tqdm

# %% [markdown]
# #### Import Dataset
# Assign labels for the images based on the subdirectories to obtain X(images array) and y (labels).
#
# Ensure that the test data contains atleast one image from each category.

# %%
# iterate through all folders, load each image

trainAmt = 0.9
allFaces = []
labels = []

for i in range(1,41):
    for j in range(1,11):
        imgPath = os.path.join("ATnT", "s" + str(i), str(j) + ".pgm")
        img = cv2.imread(imgPath, -1)

        allFaces.append(img)
        labels.append(i)

# shuffle
randomOrder = np.random.permutation(len(labels))
allFaces = np.array(allFaces)[randomOrder]
labels = np.array(labels)[randomOrder]

# split
trainFaces = allFaces[:int(trainAmt*len(allFaces))]
trainLabels = labels[:int(trainAmt*len(allFaces))]

testFaces = allFaces[int(trainAmt*len(allFaces)): ]
testLabels = labels[int(trainAmt*len(allFaces)): ]

# 112x92 (= 10304) grayscale images,  360 in train, 40 in test
print(trainFaces.shape, trainLabels.shape)
# Out:
# (360, 112, 92) (360,)

# %% [markdown]
# #### Implement PCA Algorithm.

# %% [markdown]
# Explain your steps with comments and write a brief explanation of the method.

# %%
def principalComponentAnalysis(X, numComponents):
    """
    Implement pca in the following function by taking the following arguements:
    1. X(images array)
    2. number of components
    The function must return the eigen vectors (principal components) also termed "Eigen faces"
    """

    X_flat = X.reshape(X.shape[0], -1)


    print("X_flat shape (before reshape):", X_flat.shape)


    if len(X_flat.shape) > 1 and X_flat.shape[1] == 1:
        X_flat = X_flat.flatten()


    print("X_flat shape (after reshape):", X_flat.shape)


    if np.any(X_flat is None):
        raise ValueError("X_flat contains None values. Please check the input data.")


    meanFace = np.mean(X_flat, axis=0, keepdims=True)


    print("meanFace shape:", meanFace.shape)


    centered_faces = X_flat - meanFace


    cov_matrix = np.cov(centered_faces, rowvar=False)


    eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)


    indices = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[indices]
    eigenvectors = eigenvectors[:, indices]


    eigenFaces = eigenvectors[:, :numComponents]

    return meanFace, eigenFaces

# %%
def plot_eigenfaces(eigenFaces, numComponents):
    """
    Plot the eigenfaces generated by PCA
    """
    plt.figure(figsize=(15, 8))
    for i in range(min(25, numComponents)):
        plt.subplot(5, 5, i + 1)
        plt.imshow(np.reshape(eigenFaces[:, i], (112, 92)), cmap='gray')
        plt.title(f'Eigenface {i + 1}')

    plt.show()


numComponents = 100


meanFace, eigenFaces = principalComponentAnalysis(trainFaces, numComponents)


plot_eigenfaces(eigenFaces, numComponents)
# Out:
# X_flat shape (before reshape): (360, 10304)
# X_flat shape (after reshape): (360, 10304)
# meanFace shape: (1, 10304)

# %%
# plot the eigen faces
# %matplotlib inline

# %% [markdown]
# #### Implement Image Reconstruction from Eigenfaces

# %% [markdown]
# Explain your steps with comments and write a brief explanation of the method.

# %%
def imageReconstruction(testFaces, eigenFaces, meanFace, numComponents):
    """
    Reconstruct faces using a specified number of eigenfaces.

    Parameters:
    - testFaces: Array of flattened representations of input faces.
    - eigenFaces: Matrix containing the eigenfaces as columns.
    - meanFace: Mean face of the training data.
    - numComponents: Number of components (eigenfaces) to use.

    Returns:
    - reconstructedFaces: Array of reconstructed faces.
    """






    meanFace_flat = meanFace.flatten()


    centered_testFaces = testFaces - meanFace_flat.reshape((1, -1))





    weights = np.dot(centered_testFaces, eigenFaces[:, :numComponents])





    reconstructedFaces = meanFace_flat + np.dot(weights, eigenFaces[:, :numComponents].T)




    return reconstructedFaces

# %%
# plot recontructions here
# %matplotlib inline

# %%
test_face_index = 0
test_face = testFaces[test_face_index].flatten()
reconstructed_face = imageReconstruction(test_face, eigenFaces, meanFace,numComponents)

original_face_reshaped = test_face.reshape((112, 92))
reconstructed_face_reshaped = reconstructed_face.reshape((112, 92))

plt.figure(figsize=(8, 4))


plt.subplot(1, 2, 1)
plt.imshow(original_face_reshaped, cmap='gray')
plt.title('Original Face')


plt.subplot(1, 2, 2)
plt.imshow(reconstructed_face_reshaped, cmap='gray')
plt.title('Reconstructed Face')

plt.show()

# %% [markdown]
# #### Visualisation
# Visualise the results for different number of factors(pc = 5, 10, 50, 100, etc.)
#
# **Note:** Ensure that the images are labelled appropriately.

# %%
def displayNfactors(testFaces, eigenFaces, meanFace, numComponentsList):
    """
    Display reconstructed faces for different numbers of components.

    Parameters:
    - testFaces: Array of flattened representations of input faces.
    - eigenFaces: Matrix containing the eigenfaces as columns.
    - meanFace: Mean face of the training data.
    - numComponentsList: List of numbers of components to display.

    Returns:
    - None
    """

    plt.figure(figsize=(15, 10))

    for i, numComponents in enumerate(numComponentsList, 1):

        reconstructedFaces = [imageReconstruction(testFace.flatten(), eigenFaces, meanFace, numComponents) for testFace in testFaces]


        for j, reconstructedFace in enumerate(reconstructedFaces, 1):
            plt.subplot(len(numComponentsList), len(testFaces), (i - 1) * len(testFaces) + j)
            plt.imshow(np.reshape(reconstructedFace, (112, 92)), cmap='gray')
            plt.title(f'Reconstructed Face (Components={numComponents})')

    plt.show()


displayNfactors(testFaces, eigenFaces, meanFace, [5, 10, 50, 100])

# %% [markdown]
# #### Implement face recognition module based on the norm
# Explain your steps with comments and write a brief explanation of the method.
#
# *   Test the module and report accuracies based on the number of components taken for a range of value and plot them.
# *   Also plot the mean square error vs the number of eigenvectors taken and report your observations.
# *   For further empirical analysis, plot the semi-log variant of the error plot obtained above.

# %%
def getClass(testFace, eigenFaces, meanFace, X_train, y_train, numComponents):
    weights_testFace = np.dot(testFace - meanFace.flatten(), eigenFaces[:, :numComponents])

    minError = float('inf')
    prediction = None
    reconstructedFace = None

    for i in range(X_train.shape[0]):






        weights_trainFace = np.dot(X_train[i].flatten() - meanFace.flatten(), eigenFaces[:, :numComponents])





        error = np.linalg.norm(weights_testFace - weights_trainFace)

        if error < minError:
            minError = error
            prediction = y_train[i]
            reconstructedFace = meanFace.flatten() + np.dot(weights_trainFace, eigenFaces[:, :numComponents].T)

    return reconstructedFace, minError, prediction

# %% [markdown]
# Iterate through all the images in the test data and test the accuracy by taking different number of components

# %%
components = [3, 5, 10, 20, 30, 40, 50]
mse_values = []

for numComponents in components:
    total_images = len(testFaces)
    correct_predictions = 0

    for i in range(total_images):
        test_face = testFaces[i].flatten()
        true_label = testLabels[i]


        mean_face_flat = meanFace.flatten()


        weights_trainFace = np.dot(trainFaces[i].flatten() - mean_face_flat, eigenFaces[:, :numComponents])


        reconstructed_face, min_error, prediction = getClass(test_face, eigenFaces[:, :numComponents], meanFace, trainFaces, trainLabels,numComponents)


        if prediction == true_label:
            correct_predictions += 1


    accuracy = correct_predictions / total_images
    mse_values.append(1 - accuracy)

for i, numComponents in enumerate(components):
    print(f"Number of Components: {numComponents}, Accuracy:{accuracy} ,MSE: {mse_values[i]}")
# Out:
# Number of Components: 3, Accuracy:1.0 ,MSE: 0.17500000000000004
# Number of Components: 5, Accuracy:1.0 ,MSE: 0.19999999999999996
# Number of Components: 10, Accuracy:1.0 ,MSE: 0.07499999999999996
# Number of Components: 20, Accuracy:1.0 ,MSE: 0.0
# Number of Components: 30, Accuracy:1.0 ,MSE: 0.0
# Number of Components: 40, Accuracy:1.0 ,MSE: 0.0
# Number of Components: 50, Accuracy:1.0 ,MSE: 0.0

# %% [markdown]
# Plot Number of eigenvectors vs Mean Square Error

# %%
# your code here
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(mse_values) + 1), mse_values, marker='o', linestyle='-')
plt.title('Number of Eigenvectors vs Mean Square Error')
plt.xlabel('Number of Eigenvectors')
plt.ylabel('Mean Square Error')
plt.grid(True)
plt.show()

# %% [markdown]
# Plot Number of eigenvectors vs Logarithmic Mean Square Error

# %%
log_mse_values = np.log(mse_values)


plt.figure(figsize=(8, 5))
plt.plot(range(1, len(log_mse_values) + 1), log_mse_values, marker='o', linestyle='-')
plt.title('Number of Eigenvectors vs Logarithmic Mean Square Error')
plt.xlabel('Number of Eigenvectors')
plt.ylabel('Logarithmic Mean Square Error')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-37-956debe101cd>:1: RuntimeWarning: divide by zero encountered in log
#   log_mse_values = np.log(mse_values)
